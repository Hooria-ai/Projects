# %%
# !pip install openai-whisper


import whisper

model = whisper.load_model('base')
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)

# %%
model.device
# Out:
# device(type='cpu')

# %%
import librosa
import IPython.display as ipd
audio_file_path = '/content/Wavin_Flag-331144.mp3'
# Load the audio file using librosa
audio_data, sample_rate = librosa.load(audio_file_path, sr=44100) # Use librosa to load the audio file and get the data as a NumPy array. sr=44100 sets the desired sample rate.

# Display the audio
ipd.Audio(audio_data, rate=sample_rate) # Use ipd.Audio to display the audio data with the correct sample rate.
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = whisper.load_audio(audio_file_path)
audio = whisper.pad_or_trim(audio)

# %%
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# %%
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")
# Out:
# Detected language: en

# %%
# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# %%
print(result.text)
# Out:
# When I get older, I will be stronger There will be freedom Just like a waging flag And then it goes back And then it goes back And then it goes back And then it goes When I get older, I will be stronger There will be freedom Just like a waging flag And then it goes back And then it goes back And then it goes back And then it goes And then it goes

# %%
! pip install gradio
import gradio as gr
import time

# %%
def transcribe(audio):

    #time.sleep(3)
    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    # audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)
    print(f"Detected language: {max(probs, key=probs.get)}")

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    return result.text

# %%
# !pip install gradio --upgrade

# %%
import gradio as gr
from transformers import pipeline

# Load Whisper model for automatic speech recognition (ASR)
# transcriber = pipeline("automatic-speech-recognition", model="openai/whisper-base", return_timestamps=True)

def transcribe_and_translate(audio):
    try:
        print('checkkkkkkkkkk111111111' , audio)
        transcriber = pipeline("automatic-speech-recognition", model="openai/whisper-base",return_timestamps=True)
        pr = transcriber(audio)
        # pr = pr[0].text
        # # Perform transcription using Whisper (default transcription in original language)
        # transcription = transcriber(audio)
        # print(transcription , "here is transcription")
        # transcribed_text = transcription.get("text", "Transcription failed.")

        # For translation, Whisper automatically detects the language and can translate to English
        # Use the translation functionality by using Whisper for translation task
        # translator = pipeline("translation", model="openai/whisper-large")
        # translation = translator(audio)
        # translated_text = translation.get("text", "Translation failed.")

        return pr

    except Exception as e:
        # Handle any errors during transcription or translation
        return f"Error in transcription: {e}", f"Error in translation: {e}"

# # # Gradio interface
gr.Interface(
    fn=transcribe_and_translate,
    inputs=gr.Audio(type="filepath", label="Upload audio file"),
    outputs= gr.Textbox(label="Transcription"),

    title="Real-time AI-based Audio Transcription and Translation Web App",
    live=True
).launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4125a00f2213a18ad7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4125a00f2213a18ad7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import librosa
import IPython.display as ipd
audio_file_path = '/content/Wavin_Flag-331144.mp3'
# Load the audio file using librosa
audio_data, sample_rate = librosa.load(audio_file_path, sr=44100) # Use librosa to load the audio file and get the data as a NumPy array. sr=44100 sets the desired sample rate.

# %%
audio = '/content/Wavin_Flag-331144.mp3'
transcriber = pipeline("automatic-speech-recognition", model="openai/whisper-base",return_timestamps=True)
pr = transcribe_and_translate(audio_file_path)
# Out:
# checkkkkkkkkkk111111111 /content/Wavin_Flag-331144.mp3
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:509: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
print(pr)
# Out:
# {'text': ' When I get older, I will be stronger There will be freedom Just like a waging flag And then it goes back And then it goes back And then it goes back And then it goes When I get older, I will be stronger There will be freedom Just like a waging flag And then it goes back And then it goes back And then it goes back And then it goes back And then it goes you', 'chunks': [{'timestamp': (0.0, 3.2), 'text': ' When I get older, I will be stronger'}, {'timestamp': (3.2, 4.82), 'text': ' There will be freedom'}, {'timestamp': (4.82, 6.96), 'text': ' Just like a waging flag'}, {'timestamp': (6.96, 8.56), 'text': ' And then it goes back'}, {'timestamp': (8.56, 10.12), 'text': ' And then it goes back'}, {'timestamp': (10.12, 11.7), 'text': ' And then it goes back'}, {'timestamp': (11.7, 12.78), 'text': ' And then it goes'}, {'timestamp': (12.78, 15.84), 'text': ' When I get older, I will be stronger'}, {'timestamp': (15.84, 17.44), 'text': ' There will be freedom'}, {'timestamp': (17.
# ...
